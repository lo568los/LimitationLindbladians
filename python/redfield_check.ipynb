# %%
from qutip import *
import matplotlib.pyplot as plt
import numpy as np
from helper_code_qutip import *
from scipy import integrate
import scipy.io

# %%
Tc_list = [0.001,0.18,0.20]
Th_list = [0.4,0.7,1.0] #For some reason, integral diverges outside this range


betalist1 = [1/Tc for Tc in Tc_list]
betalist2 = [1/Th for Th in Th_list]

gvals1 = list(np.linspace(0.001,0.01,50))
gvals2 = list(np.linspace(0.01,1,150))
gvals3 = list(np.linspace(1,10,50))

## Add the two lists
gvals = gvals1 + gvals2
gvals_ext = gvals + gvals3


print(len(betalist1),len(betalist2))

redfield_ss = []
e = 0.01
for beta2 in betalist2:
    list_red = []
    list_lle = []
    list_lle2 = []
    for g in gvals_ext:
        limit_value=700
        b=500
        N=3
        w0min=1
        w0max=w0min+e
        delta=1
        gmin=g
        gmax=g
        beta1 = beta2  #checking thermalization
            
        w0list=np.linspace(w0min,w0max,N)
        glist=np.linspace(gmin,gmax,N-1)
            
        tb=0.01
        epsilon=0.001  #low system bath coupling
        gamma1=1 #gamma1 is the coupling to left bath. It shows up in spectral bath function
        gamma2=1   #gamma2 is the coupling to the right bath.    
            
            

        mu=0
            
            
        delta=1
        mu1=mu
        mu2=mu

        H_S=create_hamiltonian2(w0list,glist,N)
    
    
        c_N=create_sm(N,2)  # we couple the Nth spin to the bath
        c_1=create_sm(N,1)
        
        
        
        eigenergies,eigstates=H_S.eigenstates()
        
        #print("eigenenergies are : ",eigenergies)
        
        spectrum=max(eigenergies)-min(eigenergies)
        
        
        
        number=len(eigenergies)
        
        integral11=np.empty((number,number),dtype=np.cdouble) #stores J * N integral for left bath
        integral12=np.empty((number,number),dtype=np.cdouble) # stores J integral (just to check) for the left bath
        integral21=np.empty((number,number),dtype=np.cdouble) #stores J*N integral for right bath
        integral22=np.empty((number,number),dtype=np.cdouble)

        #print("Integral calculations at beta2 = {} and e = {} are : ".format(beta2,e))

        for i in range(number):
            for k in range(number):
                freq=eigenergies[k]-eigenergies[i]
                #print(f"Absolute frequency  for i = {i}, k = {k} is ",np.absolute(freq))
                #print(i,k,freq)
                if( np.absolute(freq) >= 1/10**10):
                    integral11[i,k]=(-1.0j/(2*np.pi))*integrate.quad(func1,0,b,args=(tb,beta2,mu2,gamma1),limit=limit_value,weight='cauchy',wvar=eigenergies[k]-eigenergies[i])[0] #func 1
                    integral12[i,k]=(-1.0j/(2*np.pi))*integrate.quad(spectral_bath,0,b,args=(tb,gamma1),limit=limit_value,weight='cauchy',wvar=eigenergies[k]-eigenergies[i])[0]  #left bath done
                    integral21[i,k]=(-1.0j/(2*np.pi))*integrate.quad(func1,0,b,args=(tb,beta1,mu1,gamma2),limit=limit_value,weight='cauchy',wvar=eigenergies[k]-eigenergies[i])[0] #func 1
                    integral22[i,k]=(-1.0j/(2*np.pi))*integrate.quad(spectral_bath,0,b,args=(tb,gamma2),limit=limit_value,weight='cauchy',wvar=eigenergies[k]-eigenergies[i])[0]  #right bath
        
                if (np.absolute(freq)<=1/10**10):  #The problem is arising here....
                    integral11[i,k]=(-1.0j/(2*np.pi))*integrate.quad(func2,0,b,args=(tb,beta2,mu2,gamma1),limit=limit_value)[0]
                    integral12[i,k]=(-1.0j/(2*np.pi))*integrate.quad(spectral_bath_2,0,b,args=(tb,gamma1),limit=limit_value)[0]
                    integral21[i,k]=(-1.0j/(2*np.pi))*integrate.quad(func2,0,b,args=(tb,beta1,mu1,gamma2),limit=limit_value)[0]
                    integral22[i,k]=(-1.0j/(2*np.pi))*integrate.quad(spectral_bath_2,0,b,args=(tb,gamma2),limit=limit_value)[0]
                
            
            #expected=1.0j*(eigenergies[k]-eigenergies[i])/(2*tb*tb)
        #        print(i,k,integral2[i,k],expected)
    
    
        # PAY ATTENTION TO THE WAY THESE COEFFICIENTS ARE BEING COMPUTED
    
        constant12=np.empty((number,number),dtype=np.cdouble)
        constant11=np.empty((number,number),dtype=np.cdouble)
        constant21=np.empty((number,number),dtype=np.cdouble)
        constant22=np.empty((number,number),dtype=np.cdouble)
        
        
        
        for i in range(number):
            for k in range(number):
                constant12[i,k]=integral12[i,k]+integral11[i,k]+0.5*(spectral_bath(eigenergies[k]-eigenergies[i],tb,gamma1)+func1(eigenergies[k]-eigenergies[i],tb,beta2,mu2,gamma1))    #full coefficient created this is nbar+1
                constant11[i,k]=integral11[i,k]+0.5*func1(eigenergies[k]-eigenergies[i],tb,beta2,mu2,gamma1)                                       # the full coefficient is created
                
                constant22[i,k]=integral22[i,k]+integral21[i,k]+0.5*(spectral_bath(eigenergies[k]-eigenergies[i],tb,gamma2)+func1(eigenergies[k]-eigenergies[i],tb,beta1,mu1,gamma2))    #full coefficient created this is nbar+1
                constant21[i,k]=integral21[i,k]+0.5*func1(eigenergies[k]-eigenergies[i],tb,beta1,mu1,gamma2)   # the full coefficient is created
                #print(i,k,constant11[i,k],constant12[i,k],constant21[i,k],constant22[i,k])
        list1=[]
        list2=[]
        
        
        for i in range(number):
            list1.append([])
            list2.append([])
        
        
        
        matrix=np.zeros((number,number))
        
        dim=[]
        for k in range(N):
            dim.append(2)    
        
        zeromatrix=Qobj(matrix,dims=[dim,dim])
        
        
        indices1=[]
        indices2=[]
        
        
        
        
        for i in range(number):
            for k in range(number):
                list1[i].append(eigstates[i]*eigstates[i].dag()*c_1*eigstates[k]*eigstates[k].dag())
                list2[i].append(eigstates[i]*eigstates[i].dag()*c_N*eigstates[k]*eigstates[k].dag())
                
                if(tracedist(eigstates[i]*eigstates[i].dag()*c_1*eigstates[k]*eigstates[k].dag(),zeromatrix)!=0):
                    indices1.append((i,k))
                if(tracedist(eigstates[i]*eigstates[i].dag()*c_N*eigstates[k]*eigstates[k].dag(),zeromatrix)!=0):
                    indices2.append((i,k))

        pre=-1.0j*H_S
        post=1.0j*H_S
        
        L=spre(pre)+spost(post)
        
        for i in range(number):
            for k in range(number):
                vi=eigstates[i]
                vk=eigstates[k]

                #print(constant11[i,k],constant12[i,k])
                
                op1=epsilon*epsilon*constant11[i,k]*vi*vi.dag()*c_1*vk*vk.dag()*c_1.dag()
                op2=epsilon*epsilon*constant12[i,k]*c_1.dag()*vi*vi.dag()*c_1*vk*vk.dag()
                
                op3=epsilon*epsilon*constant11[i,k]*c_1.dag()
                op4=vi*vi.dag()*c_1*vk*vk.dag()
                op5=epsilon*epsilon*constant12[i,k]*c_1.dag()
                
                
                L=L+spre(-op2-op1.dag())+spost(-op1-op2.dag())
                L=L+spre(op3)*spost(op4)+spre(op4)*spost(op5)+spre(op4.dag())*spost(op3.dag()) +spre(op5.dag())*spost(op4.dag())
                
                op1=epsilon*epsilon*constant21[i,k]*vi*vi.dag()*c_N*vk*vk.dag()*c_N.dag()
                op2=epsilon*epsilon*constant22[i,k]*c_N.dag()*vi*vi.dag()*c_N*vk*vk.dag()
                
                op3=epsilon*epsilon*constant21[i,k]*c_N.dag()
                op4=vi*vi.dag()*c_N*vk*vk.dag()
                op5=epsilon*epsilon*constant22[i,k]*c_N.dag()
                
                
                L=L+spre(-op2-op1.dag())+spost(-op1-op2.dag())
                L=L+spre(op3)*spost(op4)+spre(op4)*spost(op5)+spre(op4.dag())*spost(op3.dag()) +spre(op5.dag())*spost(op4.dag())
                
                
                
        #Variables needed for for iterative-lgmres to work. 
        return_info=True
        #print('Redfield Liouvillian constructed, Computing steady-state ...')
        ss_redfield = steadystate(L,return_info=return_info)
        L_eigen = L.eigenenergies()
        print("Smallest eigenvalues of L_red are ", L_eigen[-3:])
        ss_th = (-beta2*H_S).expm()/((-beta2*H_S).expm()).tr()

        ## Calculate the trace distance between the two steady-states
        trace_dist = tracedist(ss_redfield,ss_th)
        print("Trace distance between Redfield and Thermal state is ",trace_dist)
        list_red.append(ss_redfield)
# Out:
# 3 3
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27492\1375853263.py:90: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   integral11[i,k]=(-1.0j/(2*np.pi))*integrate.quad(func2,0,b,args=(tb,beta2,mu2,gamma1),limit=limit_value)[0]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27492\1375853263.py:92: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   integral21[i,k]=(-1.0j/(2*np.pi))*integrate.quad(func2,0,b,args=(tb,beta1,mu1,gamma2),limit=limit_value)[0]
# Smallest eigenvalues of L_red are  [-2.20521649e-08-1.01019609e+00j -2.20521645e-08+1.01019609e+00j
#   1.95933617e-16+3.75397086e-16j]
# Trace distance between Redfield and Thermal state is  2.7589532669811716e-07
# Smallest eigenvalues of L_red are  [-3.01759031e-08+1.01027269e+00j -3.01759025e-08-1.01027269e+00j
#  -6.18279959e-17+1.17243107e-16j]
# Trace distance between Redfield and Thermal state is  2.7589027690911613e-07
# Smallest eigenvalues of L_red are  [-3.92031900e-08-1.0103608e+00j -3.92031896e-08+1.0103608e+00j
#  -1.91028509e-18+8.7096005e-18j]
# Trace distance between Redfield and Thermal state is  2.7588455399435925e-07
# Smallest eigenvalues of L_red are  [-4.89689777e-08-1.01045984e+00j -4.89689770e-08+1.01045984e+00j
#  -4.02213053e-17+9.78039941e-17j]
# Trace distance between Redfield and Thermal state is  2.7587823523855837e-07
# Smallest eigenvalues of L_red are  [-5.93120370e-08+1.01056925e+00j -5.93120368e-08-1.01056925e+00j
#   1.26621587e-16-1.21512950e-16j]
# Trace distance between Redfield and Thermal state is  2.758714129298643e-07
# Smallest eigenvalues of L_red are  [-7.00800286e-08+1.01068842e+00j -7.00800285e-08-1.01068842e+00j
#   3.04738642e-17-1.63250678e-16j]
# Trace distance between Redfield and Thermal state is  2.7586417583607916e-07
# Smallest eigenvalues of L_red are  [-8.11331519e-08+1.01081675e+00j -8.11331516e-08-1.01081675e+00j
#  -1.13372176e-16+4.05228831e-17j]
# Trace distance between Redfield and Thermal state is  2.7585662399792775e-07
# Smallest eigenvalues of L_red are  [-9.23464392e-08+1.01095366e+00j -9.23464388e-08-1.01095366e+00j
#  -1.35159990e-16-3.70635300e-17j]
# Trace distance between Redfield and Thermal state is  2.758488452933876e-07
# Smallest eigenvalues of L_red are  [-1.03610864e-07-1.01109856e+00j -1.03610864e-07+1.01109856e+00j
#   7.14773830e-17+1.12884120e-16j]
# Trace distance between Redfield and Thermal state is  2.7584092908148536e-07
# Smallest eigenvalues of L_red are  [-1.14833504e-07-1.01125089e+00j -1.14833503e-07+1.01125089e+00j
#   3.01383774e-17+2.78553288e-17j]
# Trace distance between Redfield and Thermal state is  2.7583295470015084e-07
# Smallest eigenvalues of L_red are  [-1.25936973e-07+1.01141014e+00j -1.25936972e-07-1.01141014e+00j
#  -1.45970313e-16-3.49206346e-16j]
# Trace distance between Redfield and Thermal state is  2.758249950528476e-07
# Smallest eigenvalues of L_red are  [-1.36858371e-07+1.01157579e+00j -1.36858369e-07-1.01157579e+00j
#  -1.01407310e-16+1.26909172e-16j]
# Trace distance between Redfield and Thermal state is  2.7581711146005694e-07
# Smallest eigenvalues of L_red are  [-1.47547904e-07+1.01174737e+00j -1.47547903e-07-1.01174737e+00j
#  -1.24379652e-16-1.84413154e-17j]
# Trace distance between Redfield and Thermal state is  2.7580935683952805e-07
# Smallest eigenvalues of L_red are  [-1.57967394e-07+1.01192445e+00j -1.57967393e-07-1.01192445e+00j
#  -4.22862515e-17-2.22820339e-17j]
# Trace distance between Redfield and Thermal state is  2.758017737703224e-07
# Smallest eigenvalues of L_red are  [-1.68088700e-07+1.01210662e+00j -1.68088698e-07-1.01210662e+00j
#  -1.14812445e-16+8.11344883e-17j]
# Trace distance between Redfield and Thermal state is  2.757943987283115e-07
# Smallest eigenvalues of L_red are  [-1.77892242e-07-1.01229348e+00j -1.77892241e-07+1.01229348e+00j
#  -3.99885139e-17+7.07734867e-17j]
# Trace distance between Redfield and Thermal state is  2.757872554155731e-07
# Smallest eigenvalues of L_red are  [-1.87365588e-07+1.01248469e+00j -1.87365587e-07-1.01248469e+00j
#   1.06255236e-17-9.20578903e-17j]
# Trace distance between Redfield and Thermal state is  2.757803672374173e-07
# Smallest eigenvalues of L_red are  [-1.96502186e-07+1.01267993e+00j -1.96502185e-07-1.01267993e+00j
#  -2.23355611e-17+7.33481244e-19j]
# Trace distance between Redfield and Thermal state is  2.7577374554633786e-07
# Smallest eigenvalues of L_red are  [-2.05300254e-07-1.01287890e+00j -2.05300254e-07+1.01287890e+00j
#  -1.36924596e-16-6.83179806e-17j]
# Trace distance between Redfield and Thermal state is  2.757674026551614e-07
# Smallest eigenvalues of L_red are  [-2.13761793e-07-1.01308131e+00j -2.13761792e-07+1.01308131e+00j
#  -8.38258558e-17-1.31593873e-16j]
# Trace distance between Redfield and Thermal state is  2.757613404091153e-07
# Smallest eigenvalues of L_red are  [-2.21891766e-07-1.01328693e+00j -2.21891766e-07+1.01328693e+00j
#  -1.56906548e-16+7.00302081e-17j]
# Trace distance between Redfield and Thermal state is  2.757555616079781e-07
# Smallest eigenvalues of L_red are  [-2.29697394e-07-1.01349551e+00j -2.29697393e-07+1.01349551e+00j
#  -2.05570502e-16-1.18383654e-16j]
# Trace distance between Redfield and Thermal state is  2.757500655327557e-07
# Smallest eigenvalues of L_red are  [-2.37187580e-07+1.01370684e+00j -2.37187580e-07-1.01370684e+00j
#  -6.15730521e-17-1.12371208e-16j]
# Trace distance between Redfield and Thermal state is  2.757448478088252e-07
# Smallest eigenvalues of L_red are  [-2.44372426e-07-1.01392073e+00j -2.44372425e-07+1.01392073e+00j
#   6.97418972e-17+1.41095135e-16j]
# Trace distance between Redfield and Thermal state is  2.757399047215387e-07
# Smallest eigenvalues of L_red are  [-2.51262844e-07+1.01413700e+00j -2.51262844e-07-1.01413700e+00j
#  -1.14274823e-17+3.49043038e-17j]
# Trace distance between Redfield and Thermal state is  2.757352291427676e-07
# Smallest eigenvalues of L_red are  [-2.57870252e-07+1.01435548e+00j -2.57870252e-07-1.01435548e+00j
#   1.28991960e-16-2.94383686e-17j]
# Trace distance between Redfield and Thermal state is  2.757308142220564e-07
# Smallest eigenvalues of L_red are  [-2.64206320e-07-1.01457602e+00j -2.64206319e-07+1.01457602e+00j
#  -4.74238638e-17-1.08940198e-16j]
# Trace distance between Redfield and Thermal state is  2.757266519656166e-07
# Smallest eigenvalues of L_red are  [-2.70282774e-07+1.01479848e+00j -2.70282773e-07-1.01479848e+00j
#  -2.46243202e-17+4.67487773e-17j]
# Trace distance between Redfield and Thermal state is  2.757227338916768e-07
# Smallest eigenvalues of L_red are  [-2.76111257e-07-1.01502274e+00j -2.76111254e-07+1.01502274e+00j
#   2.55293425e-16+1.56478554e-16j]
# Trace distance between Redfield and Thermal state is  2.7571905126381427e-07
# Smallest eigenvalues of L_red are  [-2.81703202e-07-1.01524868e+00j -2.81703202e-07+1.01524868e+00j
#  -5.25083177e-17-4.45925785e-17j]
# Trace distance between Redfield and Thermal state is  2.757155964531432e-07
# Smallest eigenvalues of L_red are  [-2.87069759e-07+1.01547618e+00j -2.87069759e-07-1.01547618e+00j
#  -3.85483707e-16+2.11543959e-16j]
# Trace distance between Redfield and Thermal state is  2.757123592677224e-07
# Smallest eigenvalues of L_red are  [-2.92221725e-07-1.01570515e+00j -2.92221724e-07+1.01570515e+00j
#   2.00400824e-16+1.81866884e-17j]
# Trace distance between Redfield and Thermal state is  2.7570933198241224e-07
# Smallest eigenvalues of L_red are  [-2.97169510e-07-1.01593549e+00j -2.97169509e-07+1.01593549e+00j
#  -2.36685177e-17+6.56822243e-17j]
# Trace distance between Redfield and Thermal state is  2.757065065911046e-07
# Smallest eigenvalues of L_red are  [-3.01923101e-07-1.01616713e+00j -3.01923100e-07+1.01616713e+00j
#   1.31152357e-16+6.83331569e-18j]
# Trace distance between Redfield and Thermal state is  2.7570387385642007e-07
# Smallest eigenvalues of L_red are  [-3.06492056e-07-1.01639998e+00j -3.06492055e-07+1.01639998e+00j
#  -2.16355688e-16+3.87945101e-16j]
# Trace distance between Redfield and Thermal state is  2.757014259157201e-07
# Smallest eigenvalues of L_red are  [-3.10885492e-07+1.01663397e+00j -3.10885492e-07-1.01663397e+00j
#  -2.78736436e-16+1.65798007e-16j]
# Trace distance between Redfield and Thermal state is  2.756991559733077e-07
# Smallest eigenvalues of L_red are  [-3.15112090e-07+1.01686903e+00j -3.15112090e-07-1.01686903e+00j
#   1.71095071e-17+3.11417467e-17j]
# Trace distance between Redfield and Thermal state is  2.756970561255334e-07
# Smallest eigenvalues of L_red are  [-3.19180097e-07-1.01710510e+00j -3.19180096e-07+1.01710510e+00j
#   2.48685620e-18-1.92221821e-18j]
# Trace distance between Redfield and Thermal state is  2.7569511859715054e-07
# Smallest eigenvalues of L_red are  [-3.23097337e-07+1.01734212e+00j -3.23097336e-07-1.01734212e+00j
#   2.15720928e-16-5.07861407e-17j]
# Trace distance between Redfield and Thermal state is  2.7569333726152427e-07
# Smallest eigenvalues of L_red are  [-3.26871225e-07+1.01758003e+00j -3.26871225e-07-1.01758003e+00j
#  -9.04306127e-17+2.30556884e-16j]
# Trace distance between Redfield and Thermal state is  2.756917057870739e-07
# Smallest eigenvalues of L_red are  [-3.30508786e-07+1.0178188e+00j -3.30508785e-07-1.0178188e+00j
#   5.65967679e-17-1.0661206e-16j]
# Trace distance between Redfield and Thermal state is  2.756902173723166e-07
# Smallest eigenvalues of L_red are  [-3.34016663e-07-1.01805837e+00j -3.34016663e-07+1.01805837e+00j
#   1.60875233e-16-5.80411978e-18j]
# Trace distance between Redfield and Thermal state is  2.7568886652372176e-07
# Smallest eigenvalues of L_red are  [-3.37401139e-07+1.01829869e+00j -3.37401138e-07-1.01829869e+00j
#   1.79518030e-16+4.90385642e-17j]
# Trace distance between Redfield and Thermal state is  2.756876478236735e-07
# Smallest eigenvalues of L_red are  [-3.40668151e-07+1.01853973e+00j -3.40668150e-07-1.01853973e+00j
#   1.85579256e-16-4.87130826e-17j]
# Trace distance between Redfield and Thermal state is  2.75686554913282e-07
# Smallest eigenvalues of L_red are  [-3.43823314e-07-1.01878146e+00j -3.43823312e-07+1.01878146e+00j
#   1.84762814e-16+1.37721434e-16j]
# Trace distance between Redfield and Thermal state is  2.75685584341795e-07
# Smallest eigenvalues of L_red are  [-3.46871931e-07-1.01902382e+00j -3.46871930e-07+1.01902382e+00j
#  -9.71215271e-18-1.59167501e-16j]
# Trace distance between Redfield and Thermal state is  2.7568473014375583e-07
# Smallest eigenvalues of L_red are  [-3.49819014e-07-1.01926680e+00j -3.49819013e-07+1.01926680e+00j
#   1.57638199e-16+7.56071034e-18j]
# Trace distance between Redfield and Thermal state is  2.7568398804290566e-07
# Smallest eigenvalues of L_red are  [-3.52669295e-07-1.01951036e+00j -3.52669294e-07+1.01951036e+00j
#  -1.17808301e-16+1.34059654e-16j]
# Trace distance between Redfield and Thermal state is  2.756833531447137e-07
# Smallest eigenvalues of L_red are  [-3.55427250e-07-1.01975448e+00j -3.55427249e-07+1.01975448e+00j
#   5.46139202e-17+1.66546995e-17j]
# Trace distance between Redfield and Thermal state is  2.756828225821257e-07
# Smallest eigenvalues of L_red are  [-3.58097107e-07+1.01999911e+00j -3.58097106e-07-1.01999911e+00j
#  -2.02191507e-17-1.52518521e-16j]
# Trace distance between Redfield and Thermal state is  2.756823914201515e-07
# Smallest eigenvalues of L_red are  [-3.58097107e-07+1.01999911e+00j -3.58097106e-07-1.01999911e+00j
#  -2.02191507e-17-1.52518521e-16j]
# Trace distance between Redfield and Thermal state is  2.756823914201515e-07
# Smallest eigenvalues of L_red are  [-4.15694729e-07+1.00499917e+00j -4.15694729e-07-1.00499917e+00j
#  -6.09290669e-17-1.60446176e-16j]
# Trace distance between Redfield and Thermal state is  2.7571317635965814e-07
# Smallest eigenvalues of L_red are  [-4.12774311e-07-1.00499918e+00j -4.12774311e-07+1.00499918e+00j
#  -3.36120050e-16-2.54330880e-16j]
# Trace distance between Redfield and Thermal state is  2.757996308979142e-07
# Smallest eigenvalues of L_red are  [-4.11557636e-07-1.00499919e+00j -4.11557635e-07+1.00499919e+00j
#   8.52084225e-18+2.13169920e-16j]
# Trace distance between Redfield and Thermal state is  2.759249812672701e-07
# Smallest eigenvalues of L_red are  [-4.10974396e-07+1.00499919e+00j -4.10974395e-07-1.00499919e+00j
#   2.30307994e-18-8.24563269e-17j]
# Trace distance between Redfield and Thermal state is  2.760851677917117e-07
# Smallest eigenvalues of L_red are  [-4.10683212e-07-1.00499920e+00j -4.10683212e-07+1.00499920e+00j
#  -2.11607542e-16-2.49595033e-16j]
# Trace distance between Redfield and Thermal state is  2.7627882542793477e-07
# Smallest eigenvalues of L_red are  [-4.10549141e-07-1.00499920e+00j -4.10549141e-07+1.00499920e+00j
#  -1.31857484e-16+7.35815136e-17j]
# Trace distance between Redfield and Thermal state is  2.765053629093105e-07
# Smallest eigenvalues of L_red are  [-4.10510397e-07-1.00499920e+00j -4.10510397e-07+1.00499920e+00j
#   1.83080730e-16+3.78127412e-16j]
# Trace distance between Redfield and Thermal state is  2.767644567302194e-07
# Smallest eigenvalues of L_red are  [-4.10535501e-07-1.00499920e+00j -4.10535501e-07+1.00499920e+00j
#   2.90447406e-16+3.64530497e-17j]
# Trace distance between Redfield and Thermal state is  2.770558910483367e-07
# Smallest eigenvalues of L_red are  [-4.10607068e-07+1.0049992e+00j -4.10607067e-07-1.0049992e+00j
#   7.17441822e-17-4.7318518e-16j]
# Trace distance between Redfield and Thermal state is  2.773794917903648e-07
# Smallest eigenvalues of L_red are  [-4.10714858e-07+1.00499920e+00j -4.10714857e-07-1.00499920e+00j
#  -4.00534352e-17-2.27496956e-16j]
# Trace distance between Redfield and Thermal state is  2.7773510022827835e-07
# Smallest eigenvalues of L_red are  [-4.10852528e-07-1.00499920e+00j -4.10852528e-07+1.00499920e+00j
#  -7.18197804e-17+6.96256131e-17j]
# Trace distance between Redfield and Thermal state is  2.7812256387725486e-07
# Smallest eigenvalues of L_red are  [-4.11015972e-07+1.00499920e+00j -4.11015972e-07-1.00499920e+00j
#  -6.73637191e-17-6.62468985e-17j]
# Trace distance between Redfield and Thermal state is  2.785417219765293e-07
# Smallest eigenvalues of L_red are  [-4.11202440e-07-1.00499920e+00j -4.11202439e-07+1.00499920e+00j
#  -1.60739748e-16-1.87699801e-16j]
# Trace distance between Redfield and Thermal state is  2.7899240981365004e-07
# Smallest eigenvalues of L_red are  [-4.11410027e-07+1.0049992e+00j -4.11410027e-07-1.0049992e+00j
#   6.23680947e-19-2.7428828e-16j]
# Trace distance between Redfield and Thermal state is  2.794744518833185e-07
# Smallest eigenvalues of L_red are  [-4.11637381e-07+1.00499920e+00j -4.11637381e-07-1.00499920e+00j
#   4.14662862e-17-7.29370474e-16j]
# Trace distance between Redfield and Thermal state is  2.7998766197401377e-07
# Smallest eigenvalues of L_red are  [-4.11883518e-07-1.00499920e+00j -4.11883517e-07+1.00499920e+00j
#  -5.85214534e-17+1.76543371e-17j]
# Trace distance between Redfield and Thermal state is  2.8053184395082503e-07
# Smallest eigenvalues of L_red are  [-4.12147704e-07+1.00499920e+00j -4.12147704e-07-1.00499920e+00j
#   2.23972187e-16+7.40094932e-16j]
# Trace distance between Redfield and Thermal state is  2.811067865332407e-07
# Smallest eigenvalues of L_red are  [-4.12429381e-07-1.0049992e+00j -4.12429381e-07+1.0049992e+00j
#   4.78030985e-17+4.9908496e-16j]
# Trace distance between Redfield and Thermal state is  2.817122668187787e-07
# Smallest eigenvalues of L_red are  [-4.12728121e-07-1.00499920e+00j -4.12728121e-07+1.00499920e+00j
#   8.18987686e-17+6.29272888e-16j]
# Trace distance between Redfield and Thermal state is  2.8234804912497225e-07
# Smallest eigenvalues of L_red are  [-4.13043582e-07+1.00499920e+00j -4.13043582e-07-1.00499920e+00j
#   2.71006958e-16-2.78146034e-16j]
# Trace distance between Redfield and Thermal state is  2.830138843568987e-07
# Smallest eigenvalues of L_red are  [-4.13375491e-07+1.00499920e+00j -4.13375490e-07-1.00499920e+00j
#  -9.34263974e-17+2.75821694e-16j]
# Trace distance between Redfield and Thermal state is  2.8370950788215464e-07
# Smallest eigenvalues of L_red are  [-4.13723624e-07-1.00499920e+00j -4.13723623e-07+1.00499920e+00j
#  -9.70341228e-17-4.34765884e-16j]
# Trace distance between Redfield and Thermal state is  2.844346414529085e-07
# Smallest eigenvalues of L_red are  [-4.14087797e-07+1.00499920e+00j -4.14087796e-07-1.00499920e+00j
#   2.49708714e-16+3.15679366e-16j]
# Trace distance between Redfield and Thermal state is  2.8518899371500505e-07
# Smallest eigenvalues of L_red are  [-4.14467850e-07+1.00499920e+00j -4.14467849e-07-1.00499920e+00j
#   4.26320115e-16+1.03985413e-15j]
# Trace distance between Redfield and Thermal state is  2.859722565898076e-07
# Smallest eigenvalues of L_red are  [-4.14863648e-07-1.00499920e+00j -4.14863647e-07+1.00499920e+00j
#  -7.36318427e-17+2.49450454e-16j]
# Trace distance between Redfield and Thermal state is  2.86784106967535e-07
# Smallest eigenvalues of L_red are  [-4.15275070e-07-1.00499920e+00j -4.15275070e-07+1.00499920e+00j
#  -1.26677165e-16-4.30251305e-16j]
# Trace distance between Redfield and Thermal state is  2.876242074542536e-07
# Smallest eigenvalues of L_red are  [-4.15702011e-07+1.00499920e+00j -4.15702011e-07-1.00499920e+00j
#   2.41766232e-16+8.68429198e-17j]
# Trace distance between Redfield and Thermal state is  2.8849220298695263e-07
# Smallest eigenvalues of L_red are  [-4.16144371e-07+1.00499920e+00j -4.16144370e-07-1.00499920e+00j
#   1.34636205e-16+1.61028199e-16j]
# Trace distance between Redfield and Thermal state is  2.893877243460473e-07
# Smallest eigenvalues of L_red are  [-4.16602061e-07+1.0049992e+00j -4.16602060e-07-1.0049992e+00j
#   1.95288081e-16-7.8570162e-17j]
# Trace distance between Redfield and Thermal state is  2.903103850397749e-07
# Smallest eigenvalues of L_red are  [-4.14110393e-07+7.08920886e-01j -4.14110393e-07-7.08920886e-01j
#   9.91578041e-17-1.94654756e-16j]
# Trace distance between Redfield and Thermal state is  2.912597821346324e-07
# Smallest eigenvalues of L_red are  [-4.11586419e-07+6.99525733e-01j -4.11586419e-07-6.99525733e-01j
#   2.54242478e-16+3.14702997e-16j]
# Trace distance between Redfield and Thermal state is  2.9223549576933397e-07
# Smallest eigenvalues of L_red are  [-4.09103367e-07-6.90130503e-01j -4.09103366e-07+6.90130503e-01j
#  -2.37053934e-16-2.83686204e-16j]
# Trace distance between Redfield and Thermal state is  2.9323708886896006e-07
# Smallest eigenvalues of L_red are  [-4.06660208e-07+6.80735202e-01j -4.06660208e-07-6.80735202e-01j
#   2.14608381e-16-2.66826971e-16j]
# Trace distance between Redfield and Thermal state is  2.942641068127547e-07
# Smallest eigenvalues of L_red are  [-4.04256028e-07-6.71339836e-01j -4.04256028e-07+6.71339836e-01j
#   2.94314898e-16+1.95691459e-16j]
# Trace distance between Redfield and Thermal state is  2.9531607773968363e-07
# Smallest eigenvalues of L_red are  [-4.01890013e-07+6.61944411e-01j -4.01890012e-07-6.61944411e-01j
#  -1.27670944e-16-1.62280885e-16j]
# Trace distance between Redfield and Thermal state is  2.9639251062959426e-07
# Smallest eigenvalues of L_red are  [-3.99561434e-07-6.52548931e-01j -3.99561433e-07+6.52548931e-01j
#   1.06753041e-16+4.14994694e-16j]
# Trace distance between Redfield and Thermal state is  2.974928994472389e-07
# Smallest eigenvalues of L_red are  [-3.97269634e-07-6.43153401e-01j -3.97269633e-07+6.43153401e-01j
#   4.90220732e-16+4.70342411e-16j]
# Trace distance between Redfield and Thermal state is  2.986167140819079e-07
# Smallest eigenvalues of L_red are  [-3.95014026e-07+6.33757824e-01j -3.95014026e-07-6.33757824e-01j
#  -3.72683921e-16-1.13365894e-19j]
# Trace distance between Redfield and Thermal state is  2.9976341232826965e-07
# Smallest eigenvalues of L_red are  [-3.92794073e-07-6.24362203e-01j -3.92794073e-07+6.24362203e-01j
#  -2.13539970e-16-8.34669542e-17j]
# Trace distance between Redfield and Thermal state is  3.009324287126846e-07
# Smallest eigenvalues of L_red are  [-3.90609292e-07+6.14966543e-01j -3.90609292e-07-6.14966543e-01j
#   2.33559138e-16+8.26353448e-17j]
# Trace distance between Redfield and Thermal state is  3.021231807678418e-07
# Smallest eigenvalues of L_red are  [-3.88459243e-07-6.05570845e-01j -3.88459243e-07+6.05570845e-01j
#  -2.21820419e-16-2.81795333e-16j]
# Trace distance between Redfield and Thermal state is  3.0333506444517765e-07
# Smallest eigenvalues of L_red are  [-3.86343524e-07+5.96175113e-01j -3.86343523e-07-5.96175113e-01j
#   7.95994249e-18-9.86449144e-17j]
# Trace distance between Redfield and Thermal state is  3.0456746086595845e-07
# Smallest eigenvalues of L_red are  [-3.84261768e-07-5.86779348e-01j -3.84261767e-07+5.86779348e-01j
#  -1.42013477e-16+6.75805484e-17j]
# Trace distance between Redfield and Thermal state is  3.0581972746610654e-07
# Smallest eigenvalues of L_red are  [-3.82213650e-07+5.77383554e-01j -3.82213650e-07-5.77383554e-01j
#  -2.90575688e-16-6.05898431e-17j]
# Trace distance between Redfield and Thermal state is  3.070912041042729e-07
# Smallest eigenvalues of L_red are  [-3.80198886e-07+5.6798773e-01j -3.80198885e-07-5.6798773e-01j
#   1.15930736e-16+2.9123850e-16j]
# Trace distance between Redfield and Thermal state is  3.083812110004586e-07
# Smallest eigenvalues of L_red are  [-3.78217252e-07+5.58591881e-01j -3.78217252e-07-5.58591881e-01j
#   1.88821620e-17-2.99116417e-16j]
# Trace distance between Redfield and Thermal state is  3.0968904860537254e-07
# Smallest eigenvalues of L_red are  [-3.76268643e-07+5.49196006e-01j -3.76268642e-07-5.49196006e-01j
#  -5.71299821e-16-5.94428274e-17j]
# Trace distance between Redfield and Thermal state is  3.110139977992051e-07
# Smallest eigenvalues of L_red are  [-3.74353202e-07+5.39800108e-01j -3.74353202e-07-5.39800108e-01j
#  -1.45704142e-16-2.00798579e-16j]
# Trace distance between Redfield and Thermal state is  3.123553198011454e-07
# Smallest eigenvalues of L_red are  [-3.72471765e-07-5.30404188e-01j -3.72471765e-07+5.30404188e-01j
#  -2.97329547e-16-4.61170092e-16j]
# Trace distance between Redfield and Thermal state is  3.137122566747268e-07
# Smallest eigenvalues of L_red are  [-3.70627540e-07+5.21008247e-01j -3.70627540e-07-5.21008247e-01j
#  -1.97046069e-17+2.24433225e-17j]
# Trace distance between Redfield and Thermal state is  3.1508403039383765e-07
# Smallest eigenvalues of L_red are  [-3.68836621e-07-5.11612286e-01j -3.68836621e-07+5.11612286e-01j
#   1.07253125e-16-1.06710633e-16j]
# Trace distance between Redfield and Thermal state is  3.1646984403416485e-07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 172
#     168 op4=vi*vi.dag()*c_1*vk*vk.dag()
#     169 op5=epsilon*epsilon*constant12[i,k]*c_1.dag()
# --> 172 L=L+spre(-op2-op1.dag())+spost(-op1-op2.dag())
#     173 L=L+spre(op3)*spost(op4)+spre(op4)*spost(op5)+spre(op4.dag())*spost(op3.dag()) +spre(op5.dag())*spost(op4.dag())
#     175 op1=epsilon*epsilon*constant21[i,k]*vi*vi.dag()*c_N*vk*vk.dag()*c_N.dag()
#
# File d:\Anaconda\envs\qiskitenv\Lib\site-packages\qutip\core\superoperator.py:29, in _map_over_compound_operators.<locals>.out(qobj)
#      27 if not isinstance(qobj, Qobj):
#      28     raise TypeError("expected a quantum object")
# ---> 29 return f(qobj)
#
# File d:\Anaconda\envs\qiskitenv\Lib\site-packages\qutip\core\superoperator.py:339, in spre(A)
#     337 if not A.isoper:
#     338     raise TypeError('Input is not a quantum operator')
# --> 339 data = _data.kron(_data.identity_like(A.data), A.data)
#     340 return Qobj(data,
#     341             dims=[A._dims, A._dims],
#     342             superrep='super',
#     343             isherm=A._isherm,
#     344             copy=False)
#
# File d:\Anaconda\envs\qiskitenv\Lib\site-packages\qutip\core\data\dispatch.pyx:392, in qutip.core.data.dispatch.Dispatcher.__call__()
#
# File d:\Anaconda\envs\qiskitenv\Lib\site-packages\qutip\core\data\kron.pyx:27, in qutip.core.data.kron.kron_dense()
#
# File d:\Anaconda\envs\qiskitenv\Lib\site-packages\qutip\core\data\kron.pyx:28, in qutip.core.data.kron.kron_dense()
#
# File d:\Anaconda\envs\qiskitenv\Lib\site-packages\numpy\lib\shape_base.py:1173, in kron(a, b)
#    1171 b_arr = expand_dims(b_arr, axis=tuple(range(0, nd*2, 2)))
#    1172 # In case of `mat`, convert result to `array`
# -> 1173 result = _nx.multiply(a_arr, b_arr, subok=(not is_any_mat))
#    1175 # Reshape back
#    1176 result = result.reshape(_nx.multiply(as_, bs))
#
# KeyboardInterrupt:
